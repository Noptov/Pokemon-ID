# %%
import pandas as pd
import numpy as np
import os
import time

# %%
poke_df = pd.read_csv("Data/pokemonstats.csv")

# %%
poke_df.columns
# Out:
# Index(['abilities', 'against_bug', 'against_dark', 'against_dragon',
#        'against_electric', 'against_fairy', 'against_fight', 'against_fire',
#        'against_flying', 'against_ghost', 'against_grass', 'against_ground',
#        'against_ice', 'against_normal', 'against_poison', 'against_psychic',
#        'against_rock', 'against_steel', 'against_water', 'attack',
#        'base_egg_steps', 'base_happiness', 'base_total', 'capture_rate',
#        'classfication', 'defense', 'experience_growth', 'height_m', 'hp',
#        'japanese_name', 'name', 'percentage_male', 'pokedex_number',
#        'sp_attack', 'sp_defense', 'speed', 'type1', 'type2', 'weight_kg',
#        'generation', 'is_legendary'],
#       dtype='object')

# %%
slim_df = poke_df.drop(['against_bug', 'against_dark', 'against_dragon',
       'against_electric', 'against_fairy', 'against_fight', 'against_fire',
       'against_flying', 'against_ghost', 'against_grass', 'against_ground',
       'against_ice', 'against_normal', 'against_poison', 'against_psychic',
       'against_rock', 'against_steel', 'against_water', 'base_egg_steps', 'base_happiness',
        'base_total', 'capture_rate', 'experience_growth', 'japanese_name'],
        axis=1)

# %%
slim_df
# Out:
#                        abilities  attack        classfication  defense  \
# 0    ['Overgrow', 'Chlorophyll']      49         Seed Pokémon       49
# 1    ['Overgrow', 'Chlorophyll']      62         Seed Pokémon       63
# 2    ['Overgrow', 'Chlorophyll']     100         Seed Pokémon      123
# 3       ['Blaze', 'Solar Power']      52       Lizard Pokémon       43
# 4       ['Blaze', 'Solar Power']      64        Flame Pokémon       58
# ..                           ...     ...                  ...      ...
# 796              ['Beast Boost']     101       Launch Pokémon      103
# 797              ['Beast Boost']     181  Drawn Sword Pokémon      131
# 798              ['Beast Boost']     101    Junkivore Pokémon       53
# 799              ['Prism Armor']     107        Prism Pokémon      101
# 800               ['Soul-Heart']      95   Artificial Pokémon      115
#
#      height_m   hp        name  percentage_male  pokedex_number  sp_attack  \
# ...

# %%
slim_df.to_csv('Data/pokestats_revised.csv', index=False)

# %% [markdown]
# ### Testing loading back

# %%
poke_stats = pd.read_csv('Data/pokestats_gen7.csv', header=[0], index_col=0)
poke_stats.columns.name = poke_stats.index.name
poke_stats.index.name = None

# %%
poke_stats
# Out:
# Pokedex Number         Name    Type 1  Type 2                    Abilities  \
# 1                 Bulbasaur     grass  poison  ['Overgrow', 'Chlorophyll']
# 2                   Ivysaur     grass  poison  ['Overgrow', 'Chlorophyll']
# 3                  Venusaur     grass  poison  ['Overgrow', 'Chlorophyll']
# 4                Charmander      fire     NaN     ['Blaze', 'Solar Power']
# 5                Charmeleon      fire     NaN     ['Blaze', 'Solar Power']
# ..                      ...       ...     ...                          ...
# 805               Stakataka      rock   steel              ['Beast Boost']
# 806             Blacephalon      fire   ghost              ['Beast Boost']
# 807                 Zeraora  electric     NaN              ['Volt Absorb']
# 808                  Meltan     steel     NaN              ['Magnet Pull']
# 809                Melmetal     steel     NaN                ['Iron Fist']
#
# ...

# %% [markdown]
# ### Cleaning Up Column Info for Display Purposes

# %%
poke_stats.loc[809]
# Out:
# Pokedex Number
# Name                      Melmetal
# Type 1                       steel
# Type 2                         NaN
# Abilities            ['Iron Fist']
# Classfication      Hex Nut Pokémon
# Height m                       2.5
# Weight kg                      800
# Male %                         NaN
# Generation                       7
# HP                             135
# Attack                         143
# Defense                        143
# Special Attack                  80
# Special Defense                 65
# Speed                           34
# Name: 809, dtype: object

# %%
poke_stats.fillna('', inplace=True)

# %%
poke_stats.Abilities = poke_stats.Abilities.str.replace(r'[^\w\s]+', '')

# %%
poke_stats['Type 1'] = poke_stats['Type 1'].str.capitalize()
poke_stats['Type 2'] = poke_stats['Type 2'].str.capitalize()

# %%
poke_stats.loc[809]
# Out:
# Pokedex Number
# Name                      Melmetal
# Type 1                       Steel
# Type 2
# Abilities                Iron Fist
# Classfication      Hex Nut Pokémon
# Height m                       2.5
# Weight kg                      800
# Male %
# Generation                       7
# HP                             135
# Attack                         143
# Defense                        143
# Special Attack                  80
# Special Defense                 65
# Speed                           34
# Name: 809, dtype: object

# %%
poke_stats.to_csv('Data/pokestats_gen7_rev2.csv')

# %%
poke_stats2 = pd.read_csv('Data/pokestats_gen7_rev2.csv', header=[0], index_col=0)
poke_stats2.columns.name = 'Pokedex Number'

# %%
poke_stats2
# Out:
# Pokedex Number         Name    Type 1  Type 2             Abilities  \
# 1                 Bulbasaur     Grass  Poison  Overgrow Chlorophyll
# 2                   Ivysaur     Grass  Poison  Overgrow Chlorophyll
# 3                  Venusaur     Grass  Poison  Overgrow Chlorophyll
# 4                Charmander      Fire     NaN     Blaze Solar Power
# 5                Charmeleon      Fire     NaN     Blaze Solar Power
# ..                      ...       ...     ...                   ...
# 805               Stakataka      Rock   Steel           Beast Boost
# 806             Blacephalon      Fire   Ghost           Beast Boost
# 807                 Zeraora  Electric     NaN           Volt Absorb
# 808                  Meltan     Steel     NaN           Magnet Pull
# 809                Melmetal     Steel     NaN             Iron Fist
#
# Pokedex Number        Classfication  Height m  Weight kg  Male %  Generation  \
# ...

# %%
poke_stats2.fillna('', inplace=True)

# %%
temp = poke_stats2.loc[poke_stats2.index == 809]

# %%
temp
# Out:
# Pokedex Number      Name Type 1 Type 2  Abilities    Classfication Height m  \
# 809             Melmetal  Steel         Iron Fist  Hex Nut Pokémon      2.5
#
# Pokedex Number Weight kg Male %  Generation   HP  Attack  Defense  \
# 809                  800                  7  135     143      143
#
# Pokedex Number  Special Attack  Special Defense  Speed
# 809                         80               65     34

# %%
temp = temp.iloc[0, 3:]

# %%
type(temp)
# Out:
# pandas.core.series.Series
